# %%
#Importing Required Packages

from PIL import Image
import pytesseract

# %%
#This function will handle the OCR processing of images

def ocr_processing(filename):

    text = pytesseract.image_to_string (Image.open(filename),config='--psm 12 --oem 3')  # We'll use Pillow's Image class to open the image and pytesseract to detect the string in the image

    return text

# %%
#Python-tesseract is a wrapper for Google’s Tesseract-OCR Engine. Here we connect with tesseract, which installed on system

pytesseract.pytesseract.tesseract_cmd = r'C:\Users\SURAJ\AppData\Local\Tesseract\tesseract.exe'

# %%
#Passing image to ocr_processing function

data = ocr_processing('allergy_sample.png')

# %%
data
# Out:
# 'LABORATORY REPORT\n\ninnevative\n\nDIAGNOSTICS\n\nleading the way\n\nNAME\n\n"ALLERGY DUMMY REPORT\n\nPAGE\n\n7\n\nSEN/AGE,\n\nFEMALE/27 YRS\n\nLABNO\n\n139999938,\n\nReferred By\n\nAddress\n\nDate of Request\n\n29012013\n\nDate of Report\n\n23012013\n\nLab ID#\n\n€301873863\n\nRIC.\n\nRefNo\n\nName of Profile. : FOOD PANELS\n\n2\n\nALLERGY TESTS\n\nRESULT\n\nUNIT REF. RANGE\n\nResult Class\n\nAllergen Name\n\nFOOD PANEL 5\n\nPEANUT\n\n0.10 KUA\n\na\n\nCODFISH\n\n0.10 KUA.\n\nif\n\nEGG WHITE\n\n2.50 KUIL\n\nMILK\n\n4.00 KUL\n\nWHEAT\n\n0.50 KUL,\n\n2\n\n‘SOYBEAN\n\n0.30 KUA.\n\nsa\n\nIndnigusiComponent\n\nieee nut,\n\n<090\n\nBeaeioeNDe\n\nby secncsgeneraton ass\n\n* cass Oln te standard stem signes: rot eect\n\n70-084\n\nVerytow\n\n035-008\n\nTow\n\n“+ND: not detecabe by IMMULITE 2000 3pAtegy\n\nOe\n\nToseaie\n\n7\n\n350-1709\n\nHa\n\n75-29\n\n25-0999\n\nVery\n\n2100\n\nLaboratory rests shoul aways be inerpreted ngether wth te ptint’s merical history clinical examination and other mestgative findings.\n\nr Carat Kwan\n\n“he repr ie aka gh te abaratory\n\nMedea Dror en Pthdogst, MBBS, FACRR\n\nforth system No rare rene\n\n(MAIN LABORATORY Frontech Cane, Lew $.02t0 6.07, 15 Jol Klang Borat Sngnpore 159357 Tot 6235 6950 Fox 6783 8563\n\n‘STAT LABORATORY Carron Mexia! Certre, Une 906 to §.07, 1 Orchard Badevara Srgepore 248649 Tet 6233 6640 Far: 6309 6642'

# %%
#Converting string to list by using split function, where \n is used as split parameter

data_extracted_from_image = data.split('\n')

# %%
data_extracted_from_image
# Out:
# ['LABORATORY REPORT',
#  '',
#  'innevative',
#  '',
#  'DIAGNOSTICS',
#  '',
#  'leading the way',
#  '',
#  'NAME',
#  '',
#  '"ALLERGY DUMMY REPORT',
#  '',
#  'PAGE',
#  '',
#  '7',
#  '',
#  'SEN/AGE,',
#  '',
#  'FEMALE/27 YRS',
#  '',
#  'LABNO',
#  '',
#  '139999938,',
#  '',
#  'Referred By',
#  '',
#  'Address',
#  '',
#  'Date of Request',
#  '',
#  '29012013',
#  '',
#  'Date of Report',
#  '',
#  '23012013',
#  '',
#  'Lab ID#',
#  '',
#  '€301873863',
#  '',
#  'RIC.',
#  '',
#  'RefNo',
#  '',
#  'Name of Profile. : FOOD PANELS',
#  '',
#  '2',
#  '',
#  'ALLERGY TESTS',
#  '',
#  'RESULT',
#  '',
#  'UNIT REF. RANGE',
#  '',
#  'Result Class',
#  '',
#  'Allergen Name',
#  '',
#  'FOOD PANEL 5',
#  '',
#  'PEANUT',
#  '',
#  '0.10 KUA',
#  '',
#  'a',
#  '',
#  'CODFISH',
#  '',
#  '0.10 KUA.',
#  '',
#  'if',
#  '',
#  'EGG WHITE',
#  '',
#  '2.50 KUIL',
#  '',
#  'MILK',
#  '',
#  '4.00 KUL',
#  '',
#  'WHEAT',
#  '',
#  '0.50 KUL,',
#  '',
#  '2',
#  '',
#  '‘SOYBEAN',
#  '',
#  '0.30 KUA.',
#  '',
#  'sa',
#  '',
#  'IndnigusiComponent',
#  '',
#  'ieee nut,',
#  '',
#  '<090',
#  '',
#  'BeaeioeNDe',
#  '',
#  'by secncsgeneraton ass',
#  '',
#  '* cass Oln te standard stem signes: rot eect',
#  '',
#  '70-084',
#  '',
#  'Verytow',
#  '',
#  '035-008',
#  '',
#  'Tow',
#  '',
#  '“+ND: not detecabe by IMMULITE 2000 3pAtegy',
#  '',
#  'Oe',
#  '',
#  'Toseaie',
#  '',
#  '7',
#  '',
#  '350-1709',
#  '',
#  'Ha',
#  '',
#  '75-29',
#  '',
#  '25-0999',
#  '',
#  'Very',
#  '',
#  '2100',
#  '',
#  'Laboratory rests shoul aways be inerpreted ngether wth te ptint’s merical history clinical examination and other mestgative findings.',
#  '',
#  'r Carat Kwan',
#  '',
#  '“he repr ie aka gh te abaratory',
#  '',
#  'Medea Dror en Pthdogst, MBBS, FACRR',
#  '',
#  'forth system No rare rene',
#  '',
#  '(MAIN LABORATORY Frontech Cane, Lew $.02t0 6.07, 15 Jol Klang Borat Sngnpore 159357 Tot 6235 6950 Fox 6783 8563',
#  '',
#  '‘STAT LABORATORY Carron Mexia! Certre, Une 906 to §.07, 1 Orchard Badevara Srgepore 248649 Tet 6233 6640 Far: 6309 6642']

# %%
#Creating new list list_without_null_values, where all null values are removed

list_without_null_values = []

list_without_null_values = [i for i in data_extracted_from_image if i]

# %%
list_without_null_values
# Out:
# ['LABORATORY REPORT',
#  'innevative',
#  'DIAGNOSTICS',
#  'leading the way',
#  'NAME',
#  '"ALLERGY DUMMY REPORT',
#  'PAGE',
#  '7',
#  'SEN/AGE,',
#  'FEMALE/27 YRS',
#  'LABNO',
#  '139999938,',
#  'Referred By',
#  'Address',
#  'Date of Request',
#  '29012013',
#  'Date of Report',
#  '23012013',
#  'Lab ID#',
#  '€301873863',
#  'RIC.',
#  'RefNo',
#  'Name of Profile. : FOOD PANELS',
#  '2',
#  'ALLERGY TESTS',
#  'RESULT',
#  'UNIT REF. RANGE',
#  'Result Class',
#  'Allergen Name',
#  'FOOD PANEL 5',
#  'PEANUT',
#  '0.10 KUA',
#  'a',
#  'CODFISH',
#  '0.10 KUA.',
#  'if',
#  'EGG WHITE',
#  '2.50 KUIL',
#  'MILK',
#  '4.00 KUL',
#  'WHEAT',
#  '0.50 KUL,',
#  '2',
#  '‘SOYBEAN',
#  '0.30 KUA.',
#  'sa',
#  'IndnigusiComponent',
#  'ieee nut,',
#  '<090',
#  'BeaeioeNDe',
#  'by secncsgeneraton ass',
#  '* cass Oln te standard stem signes: rot eect',
#  '70-084',
#  'Verytow',
#  '035-008',
#  'Tow',
#  '“+ND: not detecabe by IMMULITE 2000 3pAtegy',
#  'Oe',
#  'Toseaie',
#  '7',
#  '350-1709',
#  'Ha',
#  '75-29',
#  '25-0999',
#  'Very',
#  '2100',
#  'Laboratory rests shoul aways be inerpreted ngether wth te ptint’s merical history clinical examination and other mestgative findings.',
#  'r Carat Kwan',
#  '“he repr ie aka gh te abaratory',
#  'Medea Dror en Pthdogst, MBBS, FACRR',
#  'forth system No rare rene',
#  '(MAIN LABORATORY Frontech Cane, Lew $.02t0 6.07, 15 Jol Klang Borat Sngnpore 159357 Tot 6235 6950 Fox 6783 8563',
#  '‘STAT LABORATORY Carron Mexia! Certre, Une 906 to §.07, 1 Orchard Badevara Srgepore 248649 Tet 6233 6640 Far: 6309 6642']
